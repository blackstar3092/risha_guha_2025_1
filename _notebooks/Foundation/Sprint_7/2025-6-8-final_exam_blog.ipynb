# %%
---
layout: post
title: Final Exam Blog
description: What I Did In Trimester 3
permalink: /sprint/7/final
type: ccc
author: Risha Guha
---

# %% [markdown]
# <style>
#     /* --- Custom Numbered List Styles --- */
# .custom-list {
#     list-style-type: none;
#     counter-reset: section;
#     padding-left: 0;
# }
#
# .custom-list > li {
#     counter-increment: section;
#     font-weight: bold;
#     margin-bottom: 15px;
# }
#
# .custom-list > li::before {
#     content: counter(section) ".";
#     font-weight: bold;
#     margin-right: 8px;
#     color: #94eaff; /* Default number color */
# }
#
# /* --- Custom Colors for Each Category --- */
# .highlight {
#     font-weight: bold;
# }
#
# /* --- List Item Styling --- */
# .custom-list ul {
#     margin-top: 5px;
#     padding-left: 20px;
#     font-weight: normal;
#     color: #ddd;
# }
#
# .custom-list li ul li {
#     margin-bottom: 5px;
# }
# </style>

# %% [markdown]
# <h2><span style="font-family: Tahoma; color:#94eaff"> Projects Overview </span></h2>
#
# <ul>
#     <li><strong>DNA Dynamite</strong><br>
#         An interactive web game designed to make genetics and DNA base pairing fun and accessible. Players match DNA bases before the strand scrolls away, with trivia challenges powered by Google Gemini reinforcing concepts after mistakes. I served as <strong>Scrum Master</strong>, helping lead the team through Agile sprints, and contributed to <strong>both frontend (JavaScript OOP game logic)</strong> and <strong>backend (Python APIs for scoring and data)</strong>. The game was deployed with <strong>AWS RDS</strong> for scalable user tracking. We presented the game at <strong>Night @ the Museum</strong> and received valuable feedback from over 25 visitors.
#     </li>
#     <br>
#     <li><strong>Frostbyte</strong><br>
#         A social platform for reviewing and rating U.S. national parks. Frostbyte lets users browse park information, submit reviews, and engage with a community of fellow nature enthusiasts. I contributed to both frontend development (HTML, CSS, JS) and backend API integration using Python, with cloud deployment via AWS. This full-stack project emphasized the importance of clean design, RESTful APIs, and scalable infrastructure.
#     </li>
# </ul>
#
# <p></p>
#
# <h2><span style="font-family: Tahoma; color:#94eaff"> Unique Qualities and Credentials </span></h2>
#
# <p>
#     Over the course of the year, I earned a variety of credentials that reflect my growth as a student in both technical mastery and creative project leadership. These certificates and NFTs highlight my strengths in software development, deployment, and cross-functional teamwork.
# </p>
#
# <table style="width: 100%; border-collapse: collapse; border: 1px solid #333;">
#     <thead style="background-color: #222; color: #fff;">
#         <tr>
#             <th style="padding: 8px; border: 1px solid #444;">Credential Type</th>
#             <th style="padding: 8px; border: 1px solid #444;">Title</th>
#             <th style="padding: 8px; border: 1px solid #444;">Details</th>
#         </tr>
#     </thead>
#     <tbody style="background-color: #1a1a1a; color: #ccc;">
#         <tr>
#             <td style="padding: 8px; border: 1px solid #444;">Certificate</td>
#             <td style="padding: 8px; border: 1px solid #444;">Tools Basics</td>
#             <td style="padding: 8px; border: 1px solid #444;">Covered foundational dev tools like GitHub, GitPod, and terminal basics.</td>
#         </tr>
#         <tr>
#             <td style="padding: 8px; border: 1px solid #444;">Certificate</td>
#             <td style="padding: 8px; border: 1px solid #444;">JavaScript Essentials</td>
#             <td style="padding: 8px; border: 1px solid #444;">Gained experience in OOP and dynamic browser scripting for game logic.</td>
#         </tr>
#         <tr>
#             <td style="padding: 8px; border: 1px solid #444;">Certificate</td>
#             <td style="padding: 8px; border: 1px solid #444;">2D Game Dev + OOP</td>
#             <td style="padding: 8px; border: 1px solid #444;">Created a playable game structure using modular JavaScript.</td>
#         </tr>
#         <tr>
#             <td style="padding: 8px; border: 1px solid #444;">Certificate</td>
#             <td style="padding: 8px; border: 1px solid #444;">Data Analysis with Python</td>
#             <td style="padding: 8px; border: 1px solid #444;">Applied Python to structure and interpret data for game scoring and logic.</td>
#         </tr>
#         <tr>
#             <td style="padding: 8px; border: 1px solid #444;">Certificate</td>
#             <td style="padding: 8px; border: 1px solid #444;">Deployment – Linux/Cyber Concepts</td>
#             <td style="padding: 8px; border: 1px solid #444;">Deployed full-stack applications with a focus on security and scalability (AWS, HTTPS, JWT).</td>
#         </tr>
#         <tr>
#             <td style="padding: 8px; border: 1px solid #444;">Certificate</td>
#             <td style="padding: 8px; border: 1px solid #444;">API Development</td>
#             <td style="padding: 8px; border: 1px solid #444;">Built and integrated scoring + rating APIs for DNA Dynamite and Frostbyte.</td>
#         </tr>
#         <tr>
#             <td style="padding: 8px; border: 1px solid #444;">NFT</td>
#             <td style="padding: 8px; border: 1px solid #444;">Personalized Website NFT</td>
#             <td style="padding: 8px; border: 1px solid #444;">Custom site deployment for both a national parks platform and DNA-based game.</td>
#         </tr>
#         <tr>
#             <td style="padding: 8px; border: 1px solid #444;">NFT</td>
#             <td style="padding: 8px; border: 1px solid #444;">2D Game Design NFT</td>
#             <td style="padding: 8px; border: 1px solid #444;">Game design + mechanics for DNA Dynamite, integrating CS with science education.</td>
#         </tr>
#         <tr>
#             <td style="padding: 8px; border: 1px solid #444;">NFT</td>
#             <td style="padding: 8px; border: 1px solid #444;">Rating Feature NFT</td>
#             <td style="padding: 8px; border: 1px solid #444;">Designed average rating UI/UX and logic for Frostbyte’s review system.</td>
#         </tr>
#         <tr>
#             <td style="padding: 8px; border: 1px solid #444;">Portfolio</td>
#             <td style="padding: 8px; border: 1px solid #444;">LinkedIn Account</td>
#             <td style="padding: 8px; border: 1px solid #444;">Showcased project work, reflections, and team roles in a professional space.</td>
#         </tr>
#     </tbody>
# </table>
#
#
# <p></p>
#
# <h2><span style="font-family: Tahoma; color:#94eaff"> Homework Certification </span></h2>
#
# <ul>
#     <li>I consistently completed all assigned work throughout the year, often earning <strong>full credit or extra credit</strong> due to attention to detail and on-time submissions.</li>
#     <li>This strong foundation in fundamentals helped me perform confidently on the <strong>AP CSP Exam</strong>.</li>
#     <li><strong>Homework Submission Links:</strong></li>
#     <details>
#     <summary>Dropdown of Homework Submissions</summary>
#     <ul>
#         <li><a href="{{site.baseurl}}/sprint/7/tech_talks">Sprint 7 Tech Talk Notes </a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/hacks_1">Beneficial and Harmful Lesson Hacks</a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/hacks_2">Digital Divide Hacks</a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/hacks_3">Computing Bias Hacks</a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/hacks_4">Crowdsoucing Hacks</a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/hacks_5">Legal and Ethical Implications Hacks</a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/hacks_6">Safe Computing Hacks</a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/hacks_7">Binary Search Algorithms Hacks</a></li>
#         <li><a href="{{site.baseurl}}/github/pages/cyber_extracredit">Cyber Extra Credit</a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/hacks_8">Lists and Filtering Algorithms Hacks</a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/hacks_9">Big O Hacks<</a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/hacks_10">Undecidable Problems and Graphs and Heuristics Hacks</a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/mcreflect">MC Reflection 2021</a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/studyplan">Study Plan</a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/hacks_11">Binary</a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/hacks_12">Logic Gates</a></li>
#         <li><a href="{{site.baseurl}}/sprint/7/hacks_13">Digital Images</a></li>
#     </ul>
#     </details>
# </ul>
#
# <p></p>
#
# <h2><span style="font-family: Tahoma; color:#94eaff"> Showcasing My Work </span></h2>
#
# <ul>
#     <li><strong>Night @ the Museum – June 2025:</strong> Presented <em>DNA Dynamite</em> to over 25 visitors, including students, educators, and parents. This experience helped me strengthen my <strong>public speaking and communication skills</strong> by explaining our game’s mechanics, purpose, and development process in real time. Answering questions and gathering feedback in a busy setting boosted my confidence in presenting technical work to a non-technical audience.</li>
#     <li><strong>Pilot City Interview:</strong> Shared the educational impact and technical depth of <em>DNA Dynamite</em> with industry professionals. This experience helped me <strong>solidify my understanding of the technology stack</strong> we used, and challenged me to explain how our project aligned with biotech goals and community outreach. As a result of this interview, I was <strong>accepted into the Pilot City internship program</strong>, which was a huge milestone for my personal and professional growth.</li>
# </ul>
#
# <p>
#     Both of these showcase opportunities pushed me beyond just building software; they helped me become a more confident speaker, a clearer thinker, and someone who can connect their work to a broader purpose.
# </p>
#
#
# <p></p>
#
# <h2><span style="font-family: Tahoma; color:#94eaff"> Participation Stats and Methodology </span></h2>
#
# <ul>
#     <li><strong>DNA Dynamite Repositories:</strong>
#         <ul>
#             <li>Frontend (39 commits): <a href="https://github.com/blackstar3092/illumina_pc_frontend/graphs/contributors" target="_blank">View Contribution Graph</a></li>
#             <li>Backend (12 commits): <a href="https://github.com/blackstar3092/illumina_pc_backend/graphs/contributors" target="_blank">View Contribution Graph</a></li>
#         </ul>
#     </li>
#     <li><strong>Personal Project Commits:</strong> 92 commits<br>
#         <a href="https://github.com/blackstar3092/risha_guha_2025_1/graphs/contributors" target="_blank">View Repo</a>
#     </li>
#     <li><strong>Yearly Commit History:</strong><br>
#         <a href="https://github.com/blackstar3092" target="_blank">Visit My GitHub Profile</a>
#     </li>
# </ul>
#
# <p></p>
#
# <h4><strong>Lifetime Commits: 1,280</strong></h4>
# <ul>
#     <li>2025: 215 commits</li>
#     <li>2024: 342 commits</li>
#     <li>2023: 562 commits</li>
#     <li>2022: 132 commits</li>
#     <li>2021: 29 commits</li>
# </ul>
#
# <h4><strong>Dashboard and Predicted Grade:</strong></h4>
# <div style="width: 100%; overflow-x: auto; white-space: nowrap;">
#     <img src="{{site.baseurl}}/images/tri3final/star_issue.png" alt="Stats" style="width: 300px; display: inline-block; margin-right: 10px;">
#     <img src="{{site.baseurl}}/images/tri3final/review_issue.png" alt="Predicted Grade" style="width: 300px; display: inline-block; margin-right: 10px;">
# </div>
#
# <p></p>
#
# <h2><span style="font-family: Tahoma; color:#94eaff"> Conclusion </span></h2>
#
# <p>
#     This year has been an incredible journey of collaboration, creativity, and growth. From building educational games to leading Agile teams, I’ve developed strong technical and leadership skills. I’m proud of my work and grateful for the opportunity to apply what I’ve learned in real-world projects. These experiences, backed by my certificates, NFTs, and GitHub history, form the foundation of a portfolio I’m excited to keep building on.
# </p>

# %% [markdown]
# <h2><span style="font-family: Tahoma; color:#94eaff">  Self Assessment </span></h2>
#
# <p></p>
#
# | Skill                         | Points | Score   | Justification                                                                                                                                   |
# |-------------------------------|--------|---------|-------------------------------------------------------------------------------------------------------------------------------------------------|
# | Linkedin Interests   |    1   | 0.9       | Moderately detailed explanation of my interests and my career aspirations. Ties directly into my skills and project displays. |
# | Linkedin Projects              |   2    | 1.9     | Detailed descriptions of each project I worked on, including technical and leadership elements of projects. Project descriptions also link to deployed sites for reference.        |
# | Project Feature Blog Write Up |  2     | 1.9       | Even more detailed than Linkedin descriptions, explains my role in project development clearly                                          |
# | Homework Success Blog               | 2      | 1.8     | Homeworks were completed successfully, but I can elaborate more about what I learned from them in my blog                 |
# | Project Showcases   | 2      | 1.8       | Was very successful in demonstrating my projects, but forgot to collect additional feedback at N@TM                    |
# | Yearlong Participation and Stats   | 1      | 0.92       |  I have consistent, quality commit history, and the score predictor provides me with this score.                |
# | **Total**                     |  10    | **9.22** | Overall, I believe my work in CSP this trimester merits an A for effort and successful completion and showcasing of projects as explained in this retrospective. |
#
#
# <h3><span style="font-family: Tahoma; color:#94eaff">  Total: 9.22/10 </span></h3>
